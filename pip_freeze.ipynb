# %%
# !pip freeze
# Out:
# anyio==3.3.0
# appdirs==1.4.4
# argon2-cffi==20.1.0
# async-generator==1.10
# attrs==21.2.0
# Babel==2.9.1
# backcall==0.2.0
# bleach==4.0.0
# certifi==2021.5.30
# cffi==1.14.6
# chardet==4.0.0
# charset-normalizer==2.0.4
# colorama==0.4.4
# cycler==0.10.0
# debugpy==1.4.1
# decorator==5.0.9
# defusedxml==0.7.1
# entrypoints==0.3
# idna==3.2
# ipykernel==6.0.3
# ipython==7.26.0
# ipython-genutils==0.2.0
# jedi==0.18.0
# Jinja2==3.0.1
# json5==0.9.6
# jsonschema==3.2.0
# jupyter-client==6.1.12
# jupyter-core==4.7.1
# jupyter-server==1.10.2
# jupyterlab==3.1.2
# jupyterlab-pygments==0.1.2
# jupyterlab-server==2.6.2
# kiwisolver==1.3.1
# MarkupSafe==2.0.1
# matplotlib==3.4.2
# matplotlib-inline==0.1.2
# mistune==0.8.4
# nbclassic==0.3.1
# nbclient==0.5.3
# nbconvert==6.1.0
# nbformat==5.1.3
# nest-asyncio==1.5.1
# notebook==6.4.0
# numpy==1.20.3
# packaging==21.0
# pandocfilters==1.4.3
# parso==0.8.2
# pickleshare==0.7.5
# Pillow==8.2.0
# powershell-kernel==0.1.4
# ...

# %%
import pkg_resources
for idx, ws in enumerate(sorted([ws for ws in pkg_resources.working_set if not ws.key=='pip'], key=lambda ws : ws.key)):
    print(f'{idx:>3}: {ws}, key: {ws.key}, version: {ws.version}')
# Out:
#   0: appdirs 1.4.4, key: appdirs, version: 1.4.4
#   1: argon2-cffi 20.1.0, key: argon2-cffi, version: 20.1.0
#   2: async-generator 1.10, key: async-generator, version: 1.10
#   3: attrs 21.2.0, key: attrs, version: 21.2.0
#   4: backcall 0.2.0, key: backcall, version: 0.2.0
#   5: bcrypt 3.2.0, key: bcrypt, version: 3.2.0
#   6: bleach 3.3.0, key: bleach, version: 3.3.0
#   7: certifi 2021.5.30, key: certifi, version: 2021.5.30
#   8: cffi 1.14.5, key: cffi, version: 1.14.5
#   9: chardet 4.0.0, key: chardet, version: 4.0.0
#  10: colorama 0.4.4, key: colorama, version: 0.4.4
#  11: cryptography 3.4.7, key: cryptography, version: 3.4.7
#  12: cycler 0.10.0, key: cycler, version: 0.10.0
#  13: decorator 5.0.9, key: decorator, version: 5.0.9
#  14: defusedxml 0.7.1, key: defusedxml, version: 0.7.1
#  15: entrypoints 0.3, key: entrypoints, version: 0.3
#  16: environment-kernels 1.1.1, key: environment-kernels, version: 1.1.1
#  17: fabric 2.6.0, key: fabric, version: 2.6.0
# ...
